# %% [markdown]
# 1. What is a random variable in probability theory?
#
# Ans-A random variable in probability theory is a variable that represents the outcome of a random process.
#
# There are two main types:
#
# 1.Discrete Random Variable-
#
# Takes on a countable number of distinct values
#
# Example: The number of heads in 3 coin tosses (possible values: 0, 1, 2, 3)
#
# 2.Continuous Random Variable-
#
# Takes on an uncountable number of possible values (usually any value within a range)
#
# Example: The exact time it takes to run a marathon (could be 3.42 hours, 3.421 hours, etc.)

# %% [markdown]
# 2. What are the types of random variables?
#
# Ans- 1. Discrete Random Variable-
#  Takes on countable values (finite or countably infinite).
#
# Examples:
#
# Number of students in a class
#
# Number of heads in 10 coin tosses
#
# Rolling a die (values: 1, 2, 3, 4, 5, 6)
#
#
# 2. Continuous Random Variable-
#  Takes on uncountably infinite values, typically within a range.
#
# Examples:
#
# Temperature (could be 21.3°C, 21.33°C, etc.)
#
# Time taken to complete a task
#
# Height or weight of people
#
# 3.Mixed Random Variable-
#  Has both discrete and continuous components.
#
# Example: A delivery time that’s exactly 30 minutes with some probability, but otherwise normally distributed.
#
# Used in more advanced or specialized scenarios.

# %% [markdown]
# 3.What is the difference between discrete and continuous distributions?
#
# Ans-Discrete: Defined at specific values.
# Continuous: Defined over an interval, requiring integration to find probabilities.

# %% [markdown]
# 4.What are probability distribution functions (PDF)?
#
# Ans-
# A function that describes the likelihood of different outcomes for a random variable.

# %% [markdown]
# 5.How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# Ans-PDF: Gives probability at a specific value (for discrete) or density (for continuous).
# CDF: Cumulative probability up to a certain point.

# %% [markdown]
# 6.What is a discrete uniform distribution?
#
# Ans-A distribution where all outcomes have an equal probability (e.g., rolling a fair die).

# %% [markdown]
# 7.What are the key properties of a Bernoulli distribution?
#
# Ans-Only two outcomes:
#
# -Success (1) or Failure (0).
# -Probability of success = p, failure = (1 - p).

# %% [markdown]
# 8.What is the binomial distribution, and how is it used in probability?
#
# Ans-Models the number of successes in a fixed number of independent Bernoulli trials.

# %% [markdown]
# 9.What is the Poisson distribution and where is it applied?
#
# Ans-Models the probability of a given number of events occurring in a fixed interval, used for rare events.

# %% [markdown]
# 10.What is a continuous uniform distribution?
#
# Ans-
# A distribution where all values in a range are equally likely.

# %% [markdown]
# 11.What are the characteristics of a normal distribution?
#
# Ans-Bell-shaped, symmetric around the mean.
#
# Mean = Median = Mode.
#
# Defined by mean (μ) and standard deviation (σ).

# %% [markdown]
# 12.What is the standard normal distribution, and why is it important?
#
# Ans-
# A normal distribution with mean = 0 and standard deviation = 1; used for standardization.

# %% [markdown]
# 13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Ans-
# The distribution of sample means approaches normality as sample size increases, regardless of the original distribution.

# %% [markdown]
# 14.How does the Central Limit Theorem relate to the normal distribution?
#
# Ans-
# It allows normal approximation of non-normal distributions when sample size is large.

# %% [markdown]
# 15.What is the application of Z statistics in hypothesis testing?
#
# Ans-
# Used to determine how many standard deviations a value is from the mean.

# %% [markdown]
# 16.How do you calculate a Z-score, and what does it represent?
#
# Ans-Formula: ( Z = \frac{(X - \mu)}{\sigma} )
#
# Represents how far a value is from the mean in terms of standard deviations.

# %% [markdown]
# 17.What are point estimates and interval estimates in statistics?
#
# Ans-Point Estimate: Single best guess of a parameter.
#
# Interval Estimate: A range within which the parameter likely falls (e.g., confidence interval).

# %% [markdown]
# 18.What is the significance of confidence intervals in statistical analysis?
#
# Ans-
# Provides a range of values that likely contain the true population parameter with a given confidence level.

# %% [markdown]
# 19.What is the relationship between a Z-score and a confidence interval?
#
# Ans-
# Z-scores determine critical values for confidence intervals.

# %% [markdown]
# 20.How are Z-scores used to compare different distributions?
#
# Ans-
# They standardize different distributions, allowing comparison on the same scale.

# %% [markdown]
# 21.What are the assumptions for applying the Central Limit Theorem?
#
# Ans-Sample size is large (usually n ≥ 30).
#
# -Independent random sampling.
#
# -Finite variance in population.

# %% [markdown]
# 22.What is the concept of expected value in a probability distribution?
#
# Ans-
# The weighted average of all possible values of a random variable.

# %% [markdown]
# 23.How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans-
# The expected value provides the long-run average outcome of a random variable based on its probability distribution.

# %% [markdown]
# Practical Questions:

# %%
#1.Generate a Random Variable and Display its Value

import numpy as np

random_variable = np.random.randint(1, 100)  # Random integer between 1 and 100
print("Generated Random Variable:", random_variable)

Generated Random Variable: 66
# Out:
#   File "<ipython-input-4-82c517fb8fbc>", line 8
#     Generated Random Variable: 66
#               ^
# SyntaxError: invalid syntax

# %%
#2.Generate a Discrete Uniform Distribution and Plot PMF

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint

low, high = 1, 6
x = np.arange(low, high + 1)
pmf_values = randint.pmf(x, low, high + 1)

plt.bar(x, pmf_values, width=0.5, color='blue', edgecolor='black')
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.title("PMF of Discrete Uniform Distribution")
plt.show()

# %%
#3.Calculate the PDF of a Bernoulli Distribution

from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

p = 0.5  # Probability of success
x_values = [0, 1]

for x in x_values:
    print(f"P(X={x}) =", bernoulli_pdf(p, x))

P(X=0) = 0.5000000000000001
P(X=1) = 0.5
# Out:
#   File "<ipython-input-7-204831b13663>", line 14
#     P(X=0) = 0.5000000000000001
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
#4.Simulate a Binomial Distribution (n=10, p=0.5) and Plot Histogram

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n, p = 10, 0.5
data = np.random.binomial(n, p, 1000)

plt.hist(data, bins=np.arange(0, 12) - 0.5, density=True, alpha=0.7, color='blue', edgecolor='black')
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xticks(range(11))
plt.show()

# %%
#5.Create and Visualize a Poisson Distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lam = 4  # Mean number of events
data = np.random.poisson(lam, 1000)

plt.hist(data, bins=np.arange(0, 15) - 0.5, density=True, alpha=0.7, color='green', edgecolor='black')
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.title("Poisson Distribution (λ=4)")
plt.show()

# %%
#6.Calculate and Plot the CDF of a Discrete Uniform Distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low, high = 1, 6
x = np.arange(low, high + 1)
cdf_values = randint.cdf(x, low, high + 1)

plt.step(x, cdf_values, where="mid", color="red")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.title("CDF of Discrete Uniform Distribution")
plt.grid()
plt.show()

# %%
#7.Generate and Visualize a Continuous Uniform Distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

data = uniform.rvs(size=1000)
plt.hist(data, bins=20, density=True, alpha=0.6, color='purple', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Continuous Uniform Distribution")
plt.show()

# %%
#8.Simulate Data from a Normal Distribution and Plot Histogram

import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 0, 1  # Mean and standard deviation
data = np.random.normal(mu, sigma, 1000)

plt.hist(data, bins=30, density=True, alpha=0.6, color='orange', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Histogram of Normal Distribution")
plt.show()

# %%
#9.Calculate Z-Scores and Plot Them

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def calculate_z_scores(data):
    return (data - np.mean(data)) / np.std(data)

data = np.random.normal(50, 10, 1000)  # Example dataset
z_scores = calculate_z_scores(data)

plt.hist(z_scores, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black')
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.title("Z-score Distribution")
plt.show()

# %%
#10.Implement the Central Limit Theorem (CLT) using a Non-Normal Distribution

import numpy as np
import matplotlib.pyplot as plt

# Generate a non-normal distribution (exponential)
population = np.random.exponential(scale=2, size=10000)

# Draw sample means (CLT effect)
sample_means = [np.mean(np.random.choice(population, 30)) for _ in range(1000)]

plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='red', edgecolor='black')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem in Action (Sample Size = 30)")
plt.show()

# %%
#15. Simulate Multiple Samples from a Normal Distribution and Verify the Central Limit Theorem

import numpy as np
import matplotlib.pyplot as plt

# Generate a non-normal population (exponential)
population = np.random.exponential(scale=2, size=10000)

# Take multiple sample means
sample_means = [np.mean(np.random.choice(population, size=30)) for _ in range(1000)]

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Demonstration")
plt.show()

# %%
#16.Calculate and Plot the Standard Normal Distribution (Mean = 0, Std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.plot(x, y, label="Standard Normal Distribution", color='blue')
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.legend()
plt.show()

# %%
#17.Generate Random Variables and Calculate Probabilities Using the Binomial Distribution

from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)

for i in range(len(x)):
    print(f"P(X={x[i]}) =", pmf_values[i])

P(X=0) = 0.0009765624999999989
P(X=1) = 0.009765625000000002
P(X=2) = 0.04394531250000004
P(X=3) = 0.1171875
P(X=4) = 0.2050781249999999
P(X=5) = 0.24609375000000003
P(X=6) = 0.2050781249999999
P(X=7) = 0.11718749999999999
P(X=8) = 0.04394531250000004
P(X=9) = 0.009765625000000002
P(X=10) = 0.0009765625
# Out:
#   File "<ipython-input-26-137353050e53>", line 12
#     P(X=0) = 0.0009765624999999989
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
#18.Calculate the Z-Score for a Given Data Point and Compare to a Standard Normal Distribution

import scipy.stats as stats

def calculate_z_score(value, mean, std):
    return (value - mean) / std

data_point = 75
mean, std = 50, 10
z_score = calculate_z_score(data_point, mean, std)

print("Z-Score:", z_score)
print("Probability from standard normal distribution:", stats.norm.cdf(z_score))

Z-Score: 2.5
Probability from standard normal distribution: 0.9937903346742238
# Out:
#   File "<ipython-input-27-a9e32cb511d3>", line 15
#     Z-Score: 2.5
#     ^
# SyntaxError: illegal target for annotation

# %%
#19.Implement Hypothesis Testing Using Z-Statistics

from scipy.stats import norm

sample_mean = 52
pop_mean = 50
std_dev = 10
n = 30

z_stat = (sample_mean - pop_mean) / (std_dev / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print("Z-Statistic:", z_stat)
print("P-Value:", p_value)

if p_value < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")

Z-Statistic: 1.0954451150103321
P-Value: 0.27332167829229803
Fail to reject the null hypothesis
# Out:
#   File "<ipython-input-28-bb63e1955219>", line 21
#     Z-Statistic: 1.0954451150103321
#     ^
# SyntaxError: illegal target for annotation

# %%
#20.Create a Confidence Interval for a Dataset

import numpy as np
import scipy.stats as stats

data = np.random.normal(50, 10, 100)
mean = np.mean(data)
std_err = stats.sem(data)
confidence = 0.95
margin = stats.t.ppf((1 + confidence) / 2, len(data)-1) * std_err

conf_interval = (mean - margin, mean + margin)
print("95% Confidence Interval:", conf_interval)

95% Confidence Interval: (np.float64(46.65752484284252), np.float64(50.718108872348864))
# Out:
#   File "<ipython-input-29-38f6a4a9e394>", line 15
#     95% Confidence Interval: (np.float64(46.65752484284252), np.float64(50.718108872348864))
#                    ^
# SyntaxError: invalid syntax

# %%
#21.Generate Data from Normal Distribution and Calculate Confidence Interval

data = np.random.normal(100, 15, 100)
mean = np.mean(data)
std_err = stats.sem(data)

confidence_interval = stats.norm.interval(0.95, loc=mean, scale=std_err)
print("95% Confidence Interval:", confidence_interval)

95% Confidence Interval: (np.float64(96.92222751545496), np.float64(103.33639215863617))
# Out:
#   File "<ipython-input-30-5d8b4d2af564>", line 10
#     95% Confidence Interval: (np.float64(96.92222751545496), np.float64(103.33639215863617))
#                    ^
# SyntaxError: invalid syntax

# %%
#22.Calculate and Visualize the PDF of a Normal Distribution

x = np.linspace(-5, 5, 1000)
pdf = norm.pdf(x, 0, 1)

plt.plot(x, pdf, color='blue')
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.title("Probability Density Function of Normal Distribution")
plt.show()

# %%
#23.Calculate and Interpret the CDF of a Poisson Distribution

from scipy.stats import poisson

lambda_ = 3
x = np.arange(0, 10)
cdf_values = poisson.cdf(x, lambda_)

plt.plot(x, cdf_values, marker="o", color="red")
plt.xlabel("Number of Events")
plt.ylabel("Cumulative Probability")
plt.title("CDF of Poisson Distribution")
plt.show()

# %%
#24.Simulate a Random Variable Using a Continuous Uniform Distribution and Calculate Expected Value

data = np.random.uniform(0, 1, 10000)
expected_value = np.mean(data)
print("Expected Value:", expected_value)

Expected Value: 0.498651572965147
# Out:
#   File "<ipython-input-35-3638f3d8a10f>", line 7
#     Expected Value: 0.498651572965147
#              ^
# SyntaxError: invalid syntax

# %%
#25.Compare the Standard Deviations of Two Datasets and Visualize the Difference

data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

std1, std2 = np.std(data1), np.std(data2)
print("Standard Deviation of Dataset 1:", std1)
print("Standard Deviation of Dataset 2:", std2)

plt.hist(data1, bins=30, alpha=0.5, label="Dataset 1 (σ=10)", color="blue")
plt.hist(data2, bins=30, alpha=0.5, label="Dataset 2 (σ=20)", color="red")
plt.legend()
plt.show()

Standard Deviation of Dataset 1: 9.957236999501566
Standard Deviation of Dataset 2: 19.748882300883377
# Out:
#   File "<ipython-input-39-8ae14353c3f5>", line 15
#     Standard Deviation of Dataset 1: 9.957236999501566
#              ^
# SyntaxError: invalid syntax

# %%
#26.Calculate the Range and Interquartile Range (IQR) of a Dataset

data = np.random.normal(100, 15, 1000)

range_value = np.max(data) - np.min(data)
iqr_value = np.percentile(data, 75) - np.percentile(data, 25)

print("Range:", range_value)
print("Interquartile Range (IQR):", iqr_value)

Range: 104.53526398498752
Interquartile Range (IQR): 21.674282076587716
# Out:
#   File "<ipython-input-40-11ea67e08a36>", line 12
#     Interquartile Range (IQR): 21.674282076587716
#                   ^
# SyntaxError: invalid syntax

# %%
#27.Implement Z-Score Normalization and Visualize Transformation

data = np.random.normal(100, 20, 1000)
z_scores = (data - np.mean(data)) / np.std(data)

plt.hist(z_scores, bins=30, alpha=0.6, color='green', edgecolor='black')
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.title("Z-Score Normalization")
plt.show()

# %%
#28.Calculate the Skewness and Kurtosis of a Normal Distribution

from scipy.stats import skew, kurtosis

data = np.random.normal(100, 15, 1000)

skewness = skew(data)
kurt = kurtosis(data)

print("Skewness:", skewness)
print("Kurtosis:", kurt)

Skewness: 0.04574841898569831
Kurtosis: -0.0485355025324008
